# %% [markdown]
# # quadrotor planning with two obstacle avoidance - MPC

# %% [markdown]
# ## Problem definition

# %%
include("ex11_data_mpc.jl");
# Out:
# WARNING: replacing module proj.
# WARNING: replacing module eX.

# %% [markdown]
# ## Load tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "mpc_utils.jl" true
@load_file "ex11_plotting.jl" false;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module mpc_utils.
# WARNING: replacing module plotter.

# %% [markdown]
# ## Run MPC

# %%
timeit_var = mpc_utils.execute_mpc!(:warm_feas,false);
# Out:
#                                  ..:: MPC Simulation ::..
# -------------------------------------------------------------------------------------------
#   Solve Instant  |   Dyn. Err.   |  Rel. Dist. to Opt. |   Solve Time (ms)  |  JuMP Status
# -------------------------------------------------------------------------------------------
#         1        |  3.734116e-03 |      5.584e-03      |      1.10e+01      |   OPTIMAL
#         2        |  3.476269e-03 |      4.660e-03      |      9.05e+00      |   OPTIMAL
#         3        |  3.408282e-03 |      3.295e-03      |      8.58e+00      |   OPTIMAL
#         4        |  3.233687e-03 |      2.338e-03      |      8.46e+00      |   OPTIMAL
#         5        |  3.180002e-03 |      4.474e-03      |      7.72e+00      |   OPTIMAL
#         6        |  3.356882e-03 |      4.425e-03      |      8.76e+00      |   OPTIMAL
#         7        |  3.366559e-03 |      7.323e-03      |      8.03e+00      |   OPTIMAL
#         8        |  3.296964e-03 |      5.873e-03      |      8.38e+00      |   OPTIMAL
#         9        |  3.314911e-03 |      4.193e-03      |      7.92e+00      |   OPTIMAL
#        10        |  3.371030e-03 |      3.613e-03      |      8.15e+00      |   OPTIMAL
#        11        |  3.336492e-03 |      3.892e-03      |      8.31e+00      |   OPTIMAL
#        12        |  2.621926e-03 |      1.993e-02      |      8.00e+00      |   OPTIMAL
#        13        |  2.807279e-03 |      2.575e-02      |      7.75e+00      |   OPTIMAL
#        14        |  2.801514e-03 |      8.786e-03      |      8.69e+00      |   OPTIMAL
#        15        |  2.578865e-03 |      3.201e-03      |      7.24e+00      |   OPTIMAL
#        16        |  2.345714e-03 |      3.623e-03      |      8.05e+00      |   OPTIMAL
#        17        |  2.428299e-03 |      5.150e-03      |      6.91e+00      |   OPTIMAL
#        18        |  2.550429e-03 |      3.105e-03      |      7.32e+00      |   OPTIMAL
#        19        |  1.409551e-03 |      1.183e-02      |      7.45e+00      |   OPTIMAL
#        20        |  1.716414e-03 |      2.007e-02      |      8.26e+00      |   OPTIMAL
#        21        |  1.778790e-03 |      3.654e-03      |      7.90e+00      |   OPTIMAL
#        22        |  1.868216e-03 |      1.227e-02      |      7.99e+00      |   OPTIMAL
#        23        |  1.549810e-03 |      2.525e-03      |      7.62e+00      |   OPTIMAL
#        24        |  1.407458e-03 |      2.862e-03      |      7.65e+00      |   OPTIMAL
#        25        |  1.396304e-03 |      2.738e-03      |      7.62e+00      |   OPTIMAL
#        26        |  1.421571e-03 |      2.628e-03      |      7.56e+00      |   OPTIMAL
#        27        |  1.356081e-03 |      2.863e-03      |      8.36e+00      |   OPTIMAL
#        28        |  1.390817e-03 |      2.492e-03      |      9.28e+00      |   OPTIMAL
#        29        |  1.383240e-03 |      1.929e-03      |      8.50e+00      |   OPTIMAL
#        30        |  1.342689e-03 |      2.177e-03      |      8.34e+00      |   OPTIMAL
#        31        |  1.378831e-03 |      2.572e-03      |      8.74e+00      |   OPTIMAL
#        32        |  1.422962e-03 |      2.104e-03      |      8.95e+00      |   OPTIMAL
#        33        |  1.420835e-03 |      2.531e-03      |      9.52e+00      |   OPTIMAL
#        34        |  1.371188e-03 |      2.819e-03      |      8.66e+00      |   OPTIMAL
#        35        |  1.373236e-03 |      2.726e-03      |      1.02e+01      |   OPTIMAL
#        36        |  1.400020e-03 |      2.516e-03      |      1.04e+01      |   OPTIMAL

# %% [markdown]
# ## Visualization

# %%
# plotter.trajectory2D(mpc_utils.xmpc,mpc_utils.umpc[1:end-1],1,eX.yy_unscl[1:eX.N])

# %%
# plotter.trajectory3D(mpc_utils.xmpc,mpc_utils.umpc[1:end-1],eX.yy_unscl[1:eX.N])

# %%
mpc_utils.plot_iter_count()

# %%
mpc_utils.plot_rd2o_dye()

# %%
mpc_utils.plot_cum_proj()

# %% [markdown]
# ## Benchmark MPC

# %%
show(timeit_var)
# Out:
#  ──────────────────────────────────────────────────────────────────────────
#                                    Time                   Allocations
#                            ──────────────────────   ───────────────────────
#      Tot / % measured:          6.98s / 19.0%            301MiB / 96.0%
#
#  Section           ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────
#  JuMP                  36    1.30s  98.1%  36.1ms    289MiB  100%   8.03MiB
#  PIPG                  36   25.2ms  1.91%   701μs     0.00B  0.00%    0.00B
#  Warm-start PIPG       36   73.3μs  0.01%  2.04μs   4.50KiB  0.00%     128B
#  Power iteration        1   37.9μs  0.00%  37.9μs     0.00B  0.00%    0.00B
#  ──────────────────────────────────────────────────────────────────────────
