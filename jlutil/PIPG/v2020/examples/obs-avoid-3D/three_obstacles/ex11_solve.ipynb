# %% [markdown]
# # quadrotor planning with three obstacle avoidance

# %% [markdown]
# ## Problem definition

# %%
include("ex11_data.jl");

# %% [markdown]
# ## Load PIPG tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "execute_utils.jl" true
@load_file "ex11_plotting.jl" false;

# %% [markdown]
# ## Solve via JuMP

# %%
exe_utils.execute_JuMP!(:mosek)
# Out:
# Termination status: OPTIMAL

# %% [markdown]
# ## Solve via PIPG

# %%
exe_utils.execute_PIPG!()
# Out:
# Total PIPG iterations          : 226
# Norm of optimum                : 29.99945804023473
# Distance to optimum (absolute) : 0.3819002943957983
# Distance to optimum (relative) : 0.012730239789118875
# Dynamics error                 : 0.004338528079508519
# (0.012730239789118875, 0.004338528079508519, 226)

# %% [markdown]
# ## Benchmark PIPG

# %%
# using BenchmarkTools
exe_utils.execute_pipg_benchmark()
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     4.959 ms (0.00% GC)
#   median time:      5.561 ms (0.00% GC)
#   mean time:        5.658 ms (0.00% GC)
#   maximum time:     8.968 ms (0.00% GC)
#   --------------
#   samples:          883
#   evals/sample:     1

# %%
# using TimerOutputs
exe_utils.execute_pipg_timeit()
# Out:
#  ──────────────────────────────────────────────────────────────────
#                            Time                   Allocations
#                    ──────────────────────   ───────────────────────
#  Tot / % measured:      317ms / 36.4%           15.7MiB / 0.00%
#
#  Section   ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────
#  PIPG          20    115ms   100%  5.76ms     0.00B   - %     0.00B
#  ──────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Diagnostic data

# %%
exe_utils.execute_PIPG!(true)
# Out:
# Power iteration estimate of σ  : 5.0878228870779125
# SVD estimate of σ              : 5.215241370961832
#
# Total PIPG iterations          : 10000
# Norm of optimum                : 29.99945804023473
# Distance to optimum (absolute) : 0.00012912595928327164
# Distance to optimum (relative) : 4.304276400929985e-6
# Dynamics error                 : 1.136805438228805e-6
# (4.304276400929985e-6, 1.136805438228805e-6, 10000)

# %% [markdown]
# ## Visualization

# %%
plotter.trajectory2D(iX.x,iX.u,2)

# %%
# plotter.trajectory3D(iX.x,iX.u,eX.y_unscl)
