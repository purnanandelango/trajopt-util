# %% [markdown]
# # 3D grasp optimization with four fingers

# %% [markdown]
# ## Problem definition

# %%
include("ex9_data.jl");
# Out:
# WARNING: replacing module proj.
# WARNING: replacing module la_utils.
# WARNING: replacing module eX.

# %% [markdown]
# ## Load PIPG tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "execute_utils.jl" true
@load_file "ex9_plotting.jl" false;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module exe_utils.
# WARNING: replacing module plotter.

# %% [markdown]
# ## Solve via JuMP

# %%
exe_utils.execute_JuMP!(:mosek)
# Out:
# Termination status: OPTIMAL

# %% [markdown]
# ## Solve via PIPG

# %%
exe_utils.execute_PIPG!()
# Out:
# Total PIPG iterations          : 87
# Norm of optimum                : 4.0
# Distance to optimum (absolute) : 0.006259088594373519
# Distance to optimum (relative) : 0.0015647721485933797
# Dynamics error                 : 0.0005940819959908417

# %% [markdown]
# ## Benchmark PIPG

# %%
# using BenchmarkTools
exe_utils.execute_pipg_benchmark()
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     45.330 ms (0.00% GC)
#   median time:      48.993 ms (0.00% GC)
#   mean time:        49.263 ms (0.00% GC)
#   maximum time:     62.248 ms (0.00% GC)
#   --------------
#   samples:          102
#   evals/sample:     1

# %%
# using TimerOutputs
exe_utils.execute_pipg_timeit()
# Out:
#  ──────────────────────────────────────────────────────────────────
#                            Time                   Allocations
#                    ──────────────────────   ───────────────────────
#  Tot / % measured:      1.22s / 82.0%           16.6MiB / 0.00%
#
#  Section   ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────
#  PIPG          20    998ms   100%  49.9ms     0.00B   - %     0.00B
#  ──────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Diagnostic data

# %%
exe_utils.execute_PIPG!(true)
# Out:
# Power iteration estimate of σ  : 8.447699906005
# SVD estimate of σ              : 8.597263855304423
#
# Total PIPG iterations          : 5000
# Norm of optimum                : 4.0
# Distance to optimum (absolute) : 0.000137059999444189
# Distance to optimum (relative) : 3.426499986104725e-5
# Dynamics error                 : 1.0138001549364617e-12

# %% [markdown]
# ## 3D Position Trace

# %% [markdown]
# ### JuMP

# %%
# plotter.trajectory3D(iX.xopt,iX.uopt)
# plotter.trajectory3D_matlab(iX.xopt,iX.uopt,eX.y_unscl,eX.N);

# %% [markdown]
# ### PIPG

# %%
plotter.trajectory3D(iX.x,iX.u)
# plotter.trajectory3D_matlab(iX.x,iX.u,eX.y_unscl,eX.N)
