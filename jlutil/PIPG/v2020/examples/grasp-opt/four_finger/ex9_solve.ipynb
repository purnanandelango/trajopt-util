# %% [markdown]
# # 3D grasp optimization with four fingers

# %% [markdown]
# ## Problem definition

# %%
include("ex9_data.jl");
# Out:
# WARNING: replacing module proj.
# WARNING: replacing module la_utils.
# WARNING: replacing module eX.

# %% [markdown]
# ## Load PIPG tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "execute_utils.jl" true
@load_file "ex9_plotting.jl" false;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module exe_utils.
# WARNING: replacing module plotter.

# %% [markdown]
# ## Solve via JuMP

# %%
exe_utils.execute_JuMP!(:mosek)
# Out:
# 0.051911115646362305

# %% [markdown]
# ## Solve via PIPG

# %%
exe_utils.execute_PIPG!(true)
# Out:
# Power iteration estimate of σ  : 8.443229567278351
# SVD estimate of σ              : 8.595292442301803
#
# Total PIPG iterations          : 10000
# Norm of optimum                : 3.9999999999999996
# Distance to optimum (absolute) : 0.00010013245318052366
# Distance to optimum (relative) : 2.503311329513092e-5
# Dynamics error                 : 2.7489122089718876e-13
# (2.503311329513092e-5, 2.7489122089718876e-13, 10000)

# %% [markdown]
# ## Benchmark PIPG

# %%
# using BenchmarkTools
exe_utils.execute_PIPG_benchmark()
# Out:
# UndefVarError: ϵp not defined
#
# Stacktrace:
#   [1] getproperty
#     @ ./Base.jl:31 [inlined]
#   [2] solver!(x::Vector{StaticArraysCore.MVector{6, Float64}}, u::Vector{StaticArraysCore.MVector{12, Float64}}, v::Vector{StaticArraysCore.MVector{6, Float64}}, w::Vector{StaticArraysCore.MVector{6, Float64}}, q::Vector{StaticArraysCore.MVector{6, Float64}}, k::Float64, αk::Float64, βk::Float64, σ1::Float64, σ2::Float64, σ3::Float64, θx1::StaticArraysCore.MVector{6, Float64}, θx2::StaticArraysCore.MVector{6, Float64}, θu1::StaticArraysCore.MVector{12, Float64}, θu2::StaticArraysCore.MVector{12, Float64}, yref::Vector{StaticArraysCore.SVector{6, Float64}}, ϵp::Float64, ϵd::Float64)
#     @ Main.pipg ~/Documents/trajopt-util/jlutil/PIPG/v2020/toolkit/pipg_suite.jl:495
#   [3] var"##core#1004"(952::Vector{StaticArraysCore.MVector{6, Float64}}, 953::Vector{StaticArraysCore.MVector{12, Float64}}, 954::Vector{StaticArraysCore.MVector{6, Float64}}, 955::Vector{StaticArraysCore.MVector{6, Float64}}, 956::Vector{StaticArraysCore.MVector{6, Float64}}, 957::Float64, 958::Float64, 959::Float64, σ1#960::Float64, 961::Float64, 962::Float64, 963::StaticArraysCore.MVector{6, Float64}, 964::StaticArraysCore.MVector{6, Float64}, 965::StaticArraysCore.MVector{12, Float64}, 966::StaticArraysCore.MVector{12, Float64}, 967::Vector{StaticArraysCore.SVector{6, Float64}}, ϵp#968::Float64, ϵd#969::Float64)
#     @ Main.exe_utils ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:489
#   [4] var"##sample#1005"(::Tuple{Vector{StaticArraysCore.MVector{6, Float64}}, Vector{StaticArraysCore.MVector{12, Float64}}, Vector{StaticArraysCore.MVector{6, Float64}}, Vector{StaticArraysCore.MVector{6, Float64}}, Vector{StaticArraysCore.MVector{6, Float64}}, Float64, Float64, Float64, Float64, Float64, Float64, StaticArraysCore.MVector{6, Float64}, StaticArraysCore.MVector{6, Float64}, StaticArraysCore.MVector{12, Float64}, StaticArraysCore.MVector{12, Float64}, Vector{StaticArraysCore.SVector{6, Float64}}, Float64, Float64}, __params::BenchmarkTools.Parameters)
#     @ Main.exe_utils ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:495
#   [5] _run(b::BenchmarkTools.Benchmark, p::BenchmarkTools.Parameters; verbose::Bool, pad::String, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ BenchmarkTools ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:99
#   [6] _run(b::BenchmarkTools.Benchmark, p::BenchmarkTools.Parameters)
#     @ BenchmarkTools ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:92
#   [7] #invokelatest#2
#     @ ./essentials.jl:729 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:726 [inlined]
#   [9] #run_result#45
#     @ ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:34 [inlined]
#  [10] run_result
#     @ ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:34 [inlined]
#  [11] run(b::BenchmarkTools.Benchmark, p::BenchmarkTools.Parameters; progressid::Nothing, nleaves::Float64, ndone::Float64, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ BenchmarkTools ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:117
#  [12] run (repeats 2 times)
#     @ ~/.julia/packages/BenchmarkTools/0owsb/src/execution.jl:117 [inlined]
#  [13] execute_PIPG_benchmark(ϵp::Float64, ϵd::Float64)
#     @ Main.exe_utils ~/Documents/trajopt-util/jlutil/PIPG/v2020/toolkit/execute_utils.jl:90
#  [14] execute_PIPG_benchmark()
#     @ Main.exe_utils ~/Documents/trajopt-util/jlutil/PIPG/v2020/toolkit/execute_utils.jl:88
#  [15] top-level scope
#     @ In[16]:2

# %%
# using TimerOutputs
exe_utils.execute_pipg_timeit()
# Out:
#  ──────────────────────────────────────────────────────────────────
#                            Time                   Allocations
#                    ──────────────────────   ───────────────────────
#  Tot / % measured:      1.22s / 82.0%           16.6MiB / 0.00%
#
#  Section   ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────
#  PIPG          20    998ms   100%  49.9ms     0.00B   - %     0.00B
#  ──────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Diagnostic data

# %%
exe_utils.execute_PIPG!(true)
# Out:
# Power iteration estimate of σ  : 8.474132429037015
# SVD estimate of σ              : 8.595292442301803
#
# Total PIPG iterations          : 10000
# Norm of optimum                : 3.9999999999999996
# Distance to optimum (absolute) : 0.00010294733066945616
# Distance to optimum (relative) : 2.5736832667364044e-5
# Dynamics error                 : 1.0072498390911733e-12
# (2.5736832667364044e-5, 1.0072498390911733e-12, 10000)

# %% [markdown]
# ## 3D Position Trace

# %% [markdown]
# ### JuMP

# %%
# plotter.trajectory3D(iX.xopt,iX.uopt)
plotter.trajectory3D_matlab(iX.xopt,iX.uopt,eX.y_unscl,eX.N);

# %% [markdown]
# ### PIPG

# %%
plotter.trajectory3D(iX.x,iX.u)
# plotter.trajectory3D_matlab(iX.x,iX.u,eX.y_unscl,eX.N)
