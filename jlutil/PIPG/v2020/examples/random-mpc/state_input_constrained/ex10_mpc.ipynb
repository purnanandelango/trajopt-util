# %% [markdown]
# ```
#                       | muaompc |  FiOrdOs |  PIPG  | Jump+gurobi | JuMP+mosek |
#     nx = 8,  nu = 4   |   1.58  |   0.23   |  0.15  |     32.2    |    25.7    |
#     nx = 20, nu = 10  |   14.0  |   6.00   |  1.56  |     48.3    |    34.9    |
#
# All times in ms
# muaompc, FiOrdOs and PIPG are warmstarted.
# ```

# %% [markdown]
# ```
# nx = 8, nu = 4
#                          ..:: FiOrdOs MPC simulation ::..
# |-------------|-----------------------------------------------|-------------------------|
# |  CVX status |  Relative error between FiOrdOs and cvx-mosek | FiOrdOs solve time (ms) |
# |-------------|-----------------------------------------------|-------------------------|
# |    Solved   |                   4.539e-04                   |         1.945e+00       |
# |    Solved   |                   6.965e-04                   |         1.054e+00       |
# |    Solved   |                   5.931e-04                   |         6.836e-01       |
# |    Solved   |                   5.935e-04                   |         4.707e-01       |
# |    Solved   |                   5.929e-04                   |         4.978e-01       |
# |    Solved   |                   6.601e-04                   |         1.151e-01       |
# |    Solved   |                   4.845e-04                   |         1.001e-01       |
# |    Solved   |                   2.522e-04                   |         1.052e-01       |
# |    Solved   |                   2.569e-04                   |         8.014e-02       |
# |    Solved   |                   2.346e-04                   |         7.936e-02       |
# |    Solved   |                   2.191e-04                   |         8.423e-02       |
# |    Solved   |                   4.831e-04                   |         1.058e-01       |
# |    Solved   |                   3.611e-04                   |         8.123e-02       |
# |    Solved   |                   4.585e-04                   |         8.710e-02       |
# |    Solved   |                   3.462e-04                   |         8.220e-02       |
# |    Solved   |                   4.816e-04                   |         8.544e-02       |
# |    Solved   |                   4.029e-04                   |         8.235e-02       |
# |    Solved   |                   4.296e-04                   |         8.328e-02       |
# |    Solved   |                   7.710e-04                   |         1.064e-01       |
# |    Solved   |                   3.684e-04                   |         1.075e-01       |
# |    Solved   |                   3.228e-04                   |         8.113e-02       |
# |    Solved   |                   3.386e-04                   |         8.269e-02       |
# |    Solved   |                   3.360e-04                   |         8.529e-02       |
# |    Solved   |                   4.855e-04                   |         8.328e-02       |
# |    Solved   |                   1.624e-04                   |         8.169e-02       |
# |    Solved   |                   2.637e-04                   |         8.532e-02       |
# |    Solved   |                   3.303e-04                   |         1.077e-01       |
# |    Solved   |                   5.659e-04                   |         7.711e-02       |
# |    Solved   |                   7.069e-04                   |         1.111e-01       |
# |    Solved   |                   2.387e-04                   |         8.480e-02       |
#
#
# Average FiOrdOs solve time: 0.231 ms
# Average relative error: 4.297e-04
# ```

# %% [markdown]
# ```
# nx = 20, nu = 10
#                           ..:: FiOrdOs MPC simulation ::..
# |-------------|-----------------------------------------------|-------------------------|
# |  CVX status |  Relative error between FiOrdOs and cvx-mosek | FiOrdOs solve time (ms) |
# |-------------|-----------------------------------------------|-------------------------|
# |    Solved   |                   4.108e-04                   |         5.427e+01       |
# |    Solved   |                   3.670e-04                   |         3.991e+01       |
# |    Solved   |                   3.432e-04                   |         2.594e+01       |
# |    Solved   |                   4.005e-04                   |         1.751e+01       |
# |    Solved   |                   4.688e-04                   |         1.001e+01       |
# |    Solved   |                   4.394e-04                   |         4.974e+00       |
# |    Solved   |                   7.096e-04                   |         3.224e+00       |
# |    Solved   |                   5.090e-04                   |         8.932e-01       |
# |    Solved   |                   5.089e-04                   |         2.206e+00       |
# |    Solved   |                   3.982e-04                   |         1.139e+00       |
# |    Solved   |                   1.728e-04                   |         4.551e-01       |
# |    Solved   |                   5.251e-04                   |         1.824e+00       |
# |    Solved   |                   7.630e-04                   |         1.287e+00       |
# |    Solved   |                   3.924e-04                   |         7.454e-01       |
# |    Solved   |                   4.508e-04                   |         8.946e-01       |
# |    Solved   |                   5.747e-04                   |         7.487e-01       |
# |    Solved   |                   6.069e-04                   |         1.544e+00       |
# |    Solved   |                   5.616e-04                   |         1.650e+00       |
# |    Solved   |                   4.919e-04                   |         1.414e+00       |
# |    Solved   |                   3.677e-04                   |         5.128e-01       |
# |    Solved   |                   4.830e-04                   |         9.740e-01       |
# |    Solved   |                   6.389e-04                   |         1.330e+00       |
# |    Solved   |                   4.746e-04                   |         1.073e+00       |
# |    Solved   |                   4.231e-04                   |         6.250e-01       |
# |    Solved   |                   5.246e-04                   |         7.482e-01       |
# |    Solved   |                   5.293e-04                   |         1.134e+00       |
# |    Solved   |                   6.969e-04                   |         7.505e-01       |
# |    Solved   |                   4.388e-04                   |         3.132e-01       |
# |    Solved   |                   6.646e-04                   |         1.878e+00       |
# |    Solved   |                   3.307e-04                   |         3.113e-01       |
#
#
# Average FiOrdOs solve time: 6.010 ms
# Average relative error: 4.889e-04
# ```

# %% [markdown]
# ```
# nx = 8, nx = 4
#                ..:: muaompc MPC simulation ::..
# -----------------------------------------------------------------
# Instant  1 | Relative d2o : 5.500306e-04 | Solve Time : 1.677 ms
# Instant  2 | Relative d2o : 1.276714e-04 | Solve Time : 1.755 ms
# Instant  3 | Relative d2o : 1.273471e-04 | Solve Time : 1.661 ms
# Instant  4 | Relative d2o : 1.274032e-04 | Solve Time : 1.645 ms
# Instant  5 | Relative d2o : 1.274071e-04 | Solve Time : 1.930 ms
# Instant  6 | Relative d2o : 1.274104e-04 | Solve Time : 1.476 ms
# Instant  7 | Relative d2o : 1.274098e-04 | Solve Time : 1.594 ms
# Instant  8 | Relative d2o : 1.274081e-04 | Solve Time : 1.544 ms
# Instant  9 | Relative d2o : 1.274077e-04 | Solve Time : 1.471 ms
# Instant 10 | Relative d2o : 1.274102e-04 | Solve Time : 1.487 ms
# Instant 11 | Relative d2o : 1.274073e-04 | Solve Time : 1.650 ms
# Instant 12 | Relative d2o : 1.274067e-04 | Solve Time : 1.559 ms
# Instant 13 | Relative d2o : 1.274078e-04 | Solve Time : 1.667 ms
# Instant 14 | Relative d2o : 1.274061e-04 | Solve Time : 1.522 ms
# Instant 15 | Relative d2o : 1.274072e-04 | Solve Time : 1.535 ms
# Instant 16 | Relative d2o : 1.274080e-04 | Solve Time : 1.524 ms
# Instant 17 | Relative d2o : 1.274061e-04 | Solve Time : 1.519 ms
# Instant 18 | Relative d2o : 1.274092e-04 | Solve Time : 1.525 ms
# Instant 19 | Relative d2o : 1.274043e-04 | Solve Time : 1.595 ms
# Instant 20 | Relative d2o : 1.274098e-04 | Solve Time : 1.541 ms
# Instant 21 | Relative d2o : 1.274043e-04 | Solve Time : 1.651 ms
# Instant 22 | Relative d2o : 1.274063e-04 | Solve Time : 1.602 ms
# Instant 23 | Relative d2o : 1.274082e-04 | Solve Time : 1.523 ms
# Instant 24 | Relative d2o : 1.274087e-04 | Solve Time : 1.508 ms
# Instant 25 | Relative d2o : 1.274078e-04 | Solve Time : 1.535 ms
# Instant 26 | Relative d2o : 1.274097e-04 | Solve Time : 1.517 ms
# Instant 27 | Relative d2o : 1.274063e-04 | Solve Time : 1.632 ms
# Instant 28 | Relative d2o : 1.274070e-04 | Solve Time : 1.585 ms
# Instant 29 | Relative d2o : 1.274089e-04 | Solve Time : 1.526 ms
# Instant 30 | Relative d2o : 1.274054e-04 | Solve Time : 1.578 ms
#
# Average muaompc solve time: 1.584 ms
# ```

# %% [markdown]
# ```
# nx = 20, nu = 10
#                ..:: muaompc MPC simulation ::..
# -----------------------------------------------------------------
# Instant  1 | Relative d2o : 5.271683e-04 | Solve Time : 14.683 ms
# Instant  2 | Relative d2o : 3.727192e-04 | Solve Time : 14.174 ms
# Instant  3 | Relative d2o : 3.701774e-04 | Solve Time : 14.125 ms
# Instant  4 | Relative d2o : 3.699483e-04 | Solve Time : 14.616 ms
# Instant  5 | Relative d2o : 3.700217e-04 | Solve Time : 13.297 ms
# Instant  6 | Relative d2o : 3.699770e-04 | Solve Time : 13.784 ms
# Instant  7 | Relative d2o : 3.699929e-04 | Solve Time : 14.462 ms
# Instant  8 | Relative d2o : 3.699870e-04 | Solve Time : 13.728 ms
# Instant  9 | Relative d2o : 3.699921e-04 | Solve Time : 13.703 ms
# Instant 10 | Relative d2o : 3.699895e-04 | Solve Time : 14.543 ms
# Instant 11 | Relative d2o : 3.699903e-04 | Solve Time : 13.958 ms
# Instant 12 | Relative d2o : 3.699860e-04 | Solve Time : 14.427 ms
# Instant 13 | Relative d2o : 3.699913e-04 | Solve Time : 13.726 ms
# Instant 14 | Relative d2o : 3.699905e-04 | Solve Time : 14.004 ms
# Instant 15 | Relative d2o : 3.699878e-04 | Solve Time : 13.086 ms
# Instant 16 | Relative d2o : 3.699867e-04 | Solve Time : 14.495 ms
# Instant 17 | Relative d2o : 3.699867e-04 | Solve Time : 13.228 ms
# Instant 18 | Relative d2o : 3.699889e-04 | Solve Time : 14.512 ms
# Instant 19 | Relative d2o : 3.699899e-04 | Solve Time : 15.097 ms
# Instant 20 | Relative d2o : 3.699877e-04 | Solve Time : 14.269 ms
# Instant 21 | Relative d2o : 3.699912e-04 | Solve Time : 14.121 ms
# Instant 22 | Relative d2o : 3.699901e-04 | Solve Time : 13.927 ms
# Instant 23 | Relative d2o : 3.699871e-04 | Solve Time : 13.729 ms
# Instant 24 | Relative d2o : 3.699908e-04 | Solve Time : 13.057 ms
# Instant 25 | Relative d2o : 3.699901e-04 | Solve Time : 14.111 ms
# Instant 26 | Relative d2o : 3.699868e-04 | Solve Time : 13.781 ms
# Instant 27 | Relative d2o : 3.699886e-04 | Solve Time : 13.682 ms
# Instant 28 | Relative d2o : 3.699885e-04 | Solve Time : 14.833 ms
# Instant 29 | Relative d2o : 3.699882e-04 | Solve Time : 13.850 ms
# Instant 30 | Relative d2o : 3.699897e-04 | Solve Time : 13.831 ms
#
# Average muaompc solve time: 14.028 ms
# ```

# %% [markdown]
# # Random MPC (state and input constrained) - MPC

# %% [markdown]
# ## Problem definition

# %%
include("ex10_data_mpc.jl");
# Out:
# WARNING: replacing module proj.
# WARNING: replacing module eX.

# %% [markdown]
# ## Load tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "mpc_utils.jl" true;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module mpc_utils.

# %% [markdown]
# ## Run MPC

# %%
timeit_var = mpc_utils.execute_mpc!(:warm_feas,false);
# Out:
#                                  ..:: MPC Simulation ::..
# -------------------------------------------------------------------------------------------
#   Solve Instant  |   Dyn. Err.   |  Rel. Dist. to Opt. |   Solve Time (ms)  |  JuMP Status
# -------------------------------------------------------------------------------------------
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-05-13
#         1        |  8.099386e-04 |      2.304e-03      |      4.17e+00      |   OPTIMAL
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2021-05-13
#         2        |  6.492856e-04 |      2.210e-03      |      3.95e+00      |   OPTIMAL
#
# --------------------------------------------
# ...
# --------------------------------------------
#
# ...

# %% [markdown]
# ## Visualization

# %%
mpc_utils.plot_iter_count()

# %%
mpc_utils.plot_rd2o_dye()

# %%
# mpc_utils.plot_cum_proj()

# %% [markdown]
# ## Benchmark MPC

# %%
# nx = 8, nu = 4
show(timeit_var)
# Out:
#  ──────────────────────────────────────────────────────────────────────────
#                                    Time                   Allocations
#                            ──────────────────────   ───────────────────────
#      Tot / % measured:          23.3s / 2.33%            110MiB / 94.0%
#
#  Section           ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────
#  JuMP + mosek          21    540ms  99.4%  25.7ms    104MiB  100%   4.94MiB
#  PIPG                  21   3.25ms  0.60%   155μs     0.00B  0.00%    0.00B
#  Warm-start PIPG       21   41.0μs  0.01%  1.95μs   2.95KiB  0.00%     144B
#  Power iteration        1   15.5μs  0.00%  15.5μs     0.00B  0.00%    0.00B
#  ──────────────────────────────────────────────────────────────────────────

# %%
# nx = 8, nu = 4
show(timeit_var)
# Out:
#  ──────────────────────────────────────────────────────────────────────────
#                                    Time                   Allocations
#                            ──────────────────────   ───────────────────────
#      Tot / % measured:          1759s / 0.04%            101MiB / 92.0%
#
#  Section           ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────
#  JuMP + gurobi         21    676ms   100%  32.2ms   93.3MiB  100%   4.44MiB
#  PIPG                  21   2.94ms  0.43%   140μs     0.00B  0.00%    0.00B
#  Warm-start PIPG       21   47.6μs  0.01%  2.27μs   2.95KiB  0.00%     144B
#  Power iteration        1   21.7μs  0.00%  21.7μs     0.00B  0.00%    0.00B
#  ──────────────────────────────────────────────────────────────────────────

# %%
# nx = 20, nu = 10
show(timeit_var)
# Out:
#  ──────────────────────────────────────────────────────────────────────────
#                                    Time                   Allocations
#                            ──────────────────────   ───────────────────────
#      Tot / % measured:          33.4s / 2.30%            251MiB / 97.3%
#
#  Section           ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────
#  JuMP + mosek          21    733ms  95.7%  34.9ms    245MiB  100%   11.6MiB
#  PIPG                  21   32.8ms  4.28%  1.56ms     0.00B  0.00%    0.00B
#  Warm-start PIPG       21    170μs  0.02%  8.08μs   4.92KiB  0.00%     240B
#  Power iteration        1    162μs  0.02%   162μs     0.00B  0.00%    0.00B
#  ──────────────────────────────────────────────────────────────────────────

# %%
# nx = 20, nu = 10
show(timeit_var)
# Out:
#  ──────────────────────────────────────────────────────────────────────────
#                                    Time                   Allocations
#                            ──────────────────────   ───────────────────────
#      Tot / % measured:          41.5s / 2.52%            230MiB / 97.0%
#
#  Section           ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────
#  JuMP + gurobi         21    1.02s  97.1%  48.4ms    223MiB  100%   10.6MiB
#  PIPG                  21   29.9ms  2.85%  1.42ms     0.00B  0.00%    0.00B
#  Power iteration        1    174μs  0.02%   174μs     0.00B  0.00%    0.00B
#  Warm-start PIPG       21    156μs  0.01%  7.44μs   4.92KiB  0.00%     240B
#  ──────────────────────────────────────────────────────────────────────────
