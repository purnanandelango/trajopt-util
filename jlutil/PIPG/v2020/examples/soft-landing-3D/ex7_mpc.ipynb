# %% [markdown]
# # 3DoF Soft Landing - MPC

# %% [markdown]
# ## Problem definition

# %%
include("ex7_data_mpc.jl");
# Out:
# WARNING: replacing module proj.
# WARNING: replacing module eX.

# %% [markdown]
# ## Load tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "mpc_utils.jl" true
@load_file "ex7_plotting.jl" false;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module mpc_utils.
# WARNING: replacing module plotter.

# %% [markdown]
# ## Run MPC

# %%
timeit_var = mpc_utils.execute_mpc_v2!(:warm_feas,false);
# Out:
#                                  ..:: MPC Simulation ::..
# -------------------------------------------------------------------------------------------
#   Solve Instant  |   Dyn. Err.   |  Rel. Dist. to Opt. |   Solve Time (ms)  |  JuMP Status
# -------------------------------------------------------------------------------------------
#         1        |  1.586721e-02 |      2.050e-03      |      5.54e+00      |   OPTIMAL
#         2        |  1.067342e-02 |      1.231e-03      |      6.81e+00      |   OPTIMAL
#         3        |  7.525404e-03 |      9.210e-04      |      6.86e+00      |   OPTIMAL
#         4        |  8.957465e-03 |      1.223e-03      |      4.94e+00      |   OPTIMAL
#         5        |  4.330031e-03 |      7.331e-04      |      5.39e+00      |   OPTIMAL
#         6        |  2.992833e-03 |      7.175e-04      |      5.57e+00      |   OPTIMAL
#         7        |  4.493094e-03 |      1.086e-03      |      5.50e+00      |   OPTIMAL
#         8        |  6.563207e-03 |      1.318e-03      |      5.53e+00      |   OPTIMAL
#         9        |  4.837628e-03 |      1.203e-03      |      6.87e+00      |   OPTIMAL
#        10        |  7.553805e-03 |      1.278e-03      |      5.08e+00      |   OPTIMAL
#        11        |  4.831403e-03 |      4.878e-04      |      5.18e+00      |   OPTIMAL
#        12        |  1.027305e-02 |      1.448e-03      |      6.12e+00      |   OPTIMAL
#        13        |  6.251618e-03 |      7.554e-04      |      4.83e+00      |   OPTIMAL
#        14        |  3.993055e-03 |      1.290e-03      |      5.96e+00      |   OPTIMAL
#        15        |  1.410487e-03 |      6.295e-04      |      6.60e+00      |   OPTIMAL
#        16        |  4.041828e-03 |      1.345e-03      |      5.58e+00      |   OPTIMAL
#        17        |  1.553655e-03 |      7.892e-04      |      7.93e+00      |   OPTIMAL
#        18        |  2.592586e-03 |      5.673e-04      |      6.88e+00      |   OPTIMAL
#        19        |  3.076181e-03 |      7.521e-04      |      5.99e+00      |   OPTIMAL
#        20        |  6.081509e-03 |      2.741e-03      |      5.47e+00      |   OPTIMAL
#        21        |  3.867114e-03 |      4.195e-04      |      6.03e+00      |   OPTIMAL

# %% [markdown]
# ## Visualization

# %%
plotter.visualization_matlab(mpc_utils.xmpc,mpc_utils.umpc)
# Out:
# >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >> >>

# %%
# plotter.trajectory3D_mpc(mpc_utils.xmpc,mpc_utils.umpc)

# %%
mpc_utils.plot_iter_count()

# %%
mpc_utils.plot_rd2o_dye()

# %%
mpc_utils.plot_cum_proj()

# %% [markdown]
# ## Benchmark MPC

# %%
show(timeit_var)
# Out:
#  ──────────────────────────────────────────────────────────────────────────
#                                    Time                   Allocations
#                            ──────────────────────   ───────────────────────
#      Tot / % measured:          8.13s / 8.18%            170MiB / 88.0%
#
#  Section           ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────────────
#  JuMP                  21    649ms  97.5%  30.9ms    150MiB  100%   7.13MiB
#  PIPG                  21   16.6ms  2.50%   791μs     0.00B  0.00%    0.00B
#  Warm-start            21   34.4μs  0.01%  1.64μs   2.63KiB  0.00%     128B
#  Power iteration        1   18.6μs  0.00%  18.6μs     0.00B  0.00%    0.00B
#  ──────────────────────────────────────────────────────────────────────────
