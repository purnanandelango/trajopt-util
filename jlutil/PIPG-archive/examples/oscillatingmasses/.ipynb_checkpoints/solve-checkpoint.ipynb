# %% [markdown]
# # Oscillating masses

# %% [markdown]
# ## Problem definition

# %%
include("problem_data.jl");

# %% [markdown]
# ## Load PIPG tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "execute_utils.jl" true
@load_file "plotting.jl" false;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module exe_utils.
# WARNING: replacing module plotter.

# %% [markdown]
# ## Solve via JuMP

# %%
exe_utils.execute_JuMP!(:mosek)
# Out:
# Termination status: OPTIMAL

# %% [markdown]
# ## Solve via PIPG

# %%
exe_utils.execute_PIPG!()
# Out:
# Total PIPG iterations          : 671
# Norm of optimum                : 1.5
# Distance to optimum (absolute) : 0.0005214478137961498
# Distance to optimum (relative) : 0.0003476318758640999
# Dynamics error                 : 0.00014265731297544412

# %% [markdown]
# ## Benchmark PIPG

# %%
# using BenchmarkTools
exe_utils.execute_pipg_benchmark()
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     5.612 ms (0.00% GC)
#   median time:      9.940 ms (0.00% GC)
#   mean time:        10.278 ms (0.00% GC)
#   maximum time:     18.103 ms (0.00% GC)
#   --------------
#   samples:          486
#   evals/sample:     1

# %%
# using TimerOutputs
exe_utils.execute_pipg_timeit()
# Out:
#  ──────────────────────────────────────────────────────────────────
#                            Time                   Allocations
#                    ──────────────────────   ───────────────────────
#  Tot / % measured:      224ms / 100%             332KiB / 0.00%
#
#  Section   ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────
#  PIPG          20    223ms   100%  11.2ms     0.00B   - %     0.00B
#  ──────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Diagnostic data

# %%
exe_utils.execute_PIPG!(true)
# Out:
# Power iteration estimate of σ  : 18.558691970002023
# SVD estimate of σ              : 18.776989792874755
#
# Total PIPG iterations          : 5000
# Norm of optimum                : 1.5
# Distance to optimum (absolute) : 1.1548186794795023e-5
# Distance to optimum (relative) : 7.698791196530016e-6
# Dynamics error                 : 8.070351335990843e-9

# %%
plotter.pos_vel_force(iX.x,iX.u)
