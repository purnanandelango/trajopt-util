# %% [markdown]
# # Oscillating masses

# %% [markdown]
# ## Problem definition

# %%
include("problem_data.jl");

# %% [markdown]
# ## Load PIPG tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "execute_utils.jl" true
@load_file "plotting.jl" false;

# %% [markdown]
# ## Solve via JuMP

# %%
exe_utils.execute_JuMP!(:mosek)
# Out:
# Termination status: OPTIMAL

# %% [markdown]
# ## Solve via PIPG

# %%
exe_utils.execute_PIPG!()
# Out:
# Total PIPG iterations          : 570
# Norm of optimum                : 1.5
# Distance to optimum (absolute) : 0.00046843530143603207
# Distance to optimum (relative) : 0.0003122902009573547
# Dynamics error                 : 0.00013125788604382172
# (0.0003122902009573547, 0.00013125788604382172, 570)

# %% [markdown]
# ## Benchmark PIPG

# %%
# using BenchmarkTools
exe_utils.execute_pipg_benchmark()
# Out:
# BenchmarkTools.Trial: 560 samples with 1 evaluation.
#  Range (min … max):  4.643 ms … 13.303 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     8.250 ms              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   8.515 ms ±  1.480 ms  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#                     ▂▄▄▄ ▁▂▄▆▄█  ▂        ▇▁▄
#   ▂▁▁▁▂▁▂▁▁▃▃▅█▆▆█▃▆████████████▇██▆▆▆██▇▇█████▆█▇▅▅▄▆▆▆▄▄▂▃ ▄
#   4.64 ms        Histogram: frequency by time        11.7 ms <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
# using TimerOutputs
exe_utils.execute_pipg_timeit()
# Out:
#  ────────────────────────────────────────────────────────────────────
#                             Time                    Allocations
#                    ───────────────────────   ────────────────────────
#  Tot / % measured:      664ms /  26.0%           32.1MiB /   0.0%
#
#  Section   ncalls     time    %tot     avg     alloc    %tot      avg
#  ────────────────────────────────────────────────────────────────────
#  PIPG          20    172ms  100.0%  8.61ms     0.00B     - %    0.00B
#  ────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Diagnostic data

# %%
exe_utils.execute_PIPG!(true)
# Out:
# Power iteration estimate of σ  : 18.326181177456462
# SVD estimate of σ              : 18.77698979287476
#
# Total PIPG iterations          : 5000
# Norm of optimum                : 1.5
# Distance to optimum (absolute) : 1.1536673185742752e-5
# Distance to optimum (relative) : 7.691115457161835e-6
# Dynamics error                 : 3.657097909536364e-9
# (7.691115457161835e-6, 3.657097909536364e-9, 5000)

# %%
plotter.pos_vel_force(iX.x,iX.u)
