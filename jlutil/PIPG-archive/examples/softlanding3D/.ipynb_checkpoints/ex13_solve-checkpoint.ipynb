# %% [markdown]
# # 3DoF Soft Landing with mass dynamics

# %% [markdown]
# ## Problem definition

# %%
load_termination_criteria = true

ϵ_pd_JuMP = 1e-8
ϵ_gap_JuMP = 1e-8

ϵ_primal = 9e-4
ϵ_dual = 9e-4
ϵ_admm = 1e-4
ϵ_admm_dual = 1e-4

include("ex13_data.jl");
# Out:
# λ / μ = 20.0
# WARNING: replacing module proj.
# WARNING: replacing module eX.

# %% [markdown]
# ## Load PIPG tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "execute_utils.jl" true
@load_file "ex13_plotting.jl" false;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module exe_utils.
# WARNING: replacing module plotter.

# %% [markdown]
# ## Solve via JuMP

# %%
exe_utils.execute_JuMP!(:mosek)
# Out:
# Termination status: OPTIMAL

# %% [markdown]
# ## Solve via PIPG

# %%
exe_utils.execute_PIPG_v3!();
# Out:
# Total PIPG iterations          : 380
# Norm of optimum                : 2655.3714572980525
# Distance to optimum (absolute) : 67.69264114508917
# Distance to optimum (relative) : 0.025492720033214924
# Dynamics error                 : 0.5356698562363906

# %% [markdown]
# ## Benchmark PIPG

# %%
# using BenchmarkTools
exe_utils.execute_pipg_v3_benchmark()
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     23.581 ms (0.00% GC)
#   median time:      24.050 ms (0.00% GC)
#   mean time:        24.540 ms (0.00% GC)
#   maximum time:     33.902 ms (0.00% GC)
#   --------------
#   samples:          204
#   evals/sample:     1

# %%
# using TimerOutputs
exe_utils.execute_pipg_v3_timeit()
# Out:
#  ──────────────────────────────────────────────────────────────────
#                            Time                   Allocations
#                    ──────────────────────   ───────────────────────
#  Tot / % measured:      517ms / 100%             259KiB / 0.00%
#
#  Section   ncalls     time   %tot     avg     alloc   %tot      avg
#  ──────────────────────────────────────────────────────────────────
#  PIPG          20    517ms   100%  25.8ms     0.00B   - %     0.00B
#  ──────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Diagnostic data

# %%
exe_utils.execute_PIPG_v3!(true);
# Out:
# Power iteration estimate of σ  : 5.028580555215878
# SVD estimate of σ              : 5.115420304728552
#
# Total PIPG iterations          : 20000
# Norm of optimum                : 2655.3714572980525
# Distance to optimum (absolute) : 11.46987591270954
# Distance to optimum (relative) : 0.004319499586841458
# Dynamics error                 : 0.00014268973040346827

# %% [markdown]
# ## 3D Position Trace

# %% [markdown]
# ### JuMP

# %%
# plotter.trajectory3D(iX.xopt,iX.uopt)

# %%
# plotter.visualization_matlab(iX.xopt,iX.uopt)

# %% [markdown]
# ### PIPG

# %%
# plotter.trajectory3D(iX.x,iX.u)
