# %% [markdown]
# # 3DoF Soft Landing with mass dynamics

# %% [markdown]
# ## Problem definition

# %%
load_termination_criteria = true

ϵ_pd_JuMP = 1e-8
ϵ_gap_JuMP = 1e-8

ϵ_primal = 9e-4
ϵ_dual = 9e-4
ϵ_admm = 1e-4
ϵ_admm_dual = 1e-4

include("problem_data.jl");
# Out:
# λ / μ = 20.0
# WARNING: replacing module proj.
# WARNING: replacing module eX.

# %% [markdown]
# ## Load PIPG tools

# %%
@load_file "pipg_suite.jl" true
@load_file "pipg_var.jl" true
@load_file "execute_utils.jl" true
@load_file "plotting.jl" false;
# Out:
# WARNING: replacing module utils.
# WARNING: replacing module common_plotter.
# WARNING: replacing module pipg.
# WARNING: replacing module iX.
# WARNING: replacing module exe_utils.
# WARNING: replacing module plotter.

# %% [markdown]
# ## Solve via JuMP

# %%
exe_utils.execute_JuMP!(:mosek)
# Out:
# Termination status: OPTIMAL

# %% [markdown]
# ## Solve via PIPG

# %%
exe_utils.execute_PIPG_v3!();
# Out:
# Total PIPG iterations          : 381
# Norm of optimum                : 2655.371461026301
# Distance to optimum (absolute) : 67.21811885853822
# Distance to optimum (relative) : 0.025314017208183152
# Dynamics error                 : 0.5343403894381282

# %% [markdown]
# ## Benchmark PIPG

# %%
# using BenchmarkTools
exe_utils.execute_pipg_v3_benchmark()
# Out:
# BenchmarkTools.Trial: 146 samples with 1 evaluation.
#  Range (min … max):  32.246 ms … 40.498 ms  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     34.283 ms              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   34.216 ms ±  1.365 ms  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#     ▂█ ▃                  ▂          ▂▂
#   ▅▃██▇██▅▅▇▅▅▅▁▅▅▃▁▁▅▆▁▅▅█▆█▃▅▃▅▅▆▆▃██▆██▃▇▇▇▅▁▅▅▃▅▁▁▃▁▅▁▁▃▃ ▃
#   32.2 ms         Histogram: frequency by time        36.9 ms <
#
#  Memory estimate: 0 bytes, allocs estimate: 0.

# %%
# using TimerOutputs
exe_utils.execute_pipg_v3_timeit()
# Out:
#  ────────────────────────────────────────────────────────────────────
#                             Time                    Allocations
#                    ───────────────────────   ────────────────────────
#  Tot / % measured:      704ms / 100.0%            206KiB /   0.0%
#
#  Section   ncalls     time    %tot     avg     alloc    %tot      avg
#  ────────────────────────────────────────────────────────────────────
#  PIPG          20    704ms  100.0%  35.2ms     0.00B     - %    0.00B
#  ────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Diagnostic data

# %%
exe_utils.execute_PIPG_v3!(true);
# Out:
# Power iteration estimate of σ  : 5.06333707926557
# SVD estimate of σ              : 5.115420304728546
#
# Total PIPG iterations          : 20000
# Norm of optimum                : 2655.371461026301
# Distance to optimum (absolute) : 11.535883670255316
# Distance to optimum (relative) : 0.004344357781790988
# Dynamics error                 : 0.009464674648704374

# %% [markdown]
# ## 3D Position Trace

# %%
include("plotting.jl")
# Out:
# UndefVarError: inlude not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[24]:1

# %% [markdown]
# ### JuMP

# %%
plotter.trajectory3D(iX.xopt,iX.uopt)
# Out:
# ! Missing number, treated as zero.
# <to be read again>
# p
# l.261 \end{axis}
# The latex command `lualatex jl_sbotqxUrSd.tex` failed
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] savepdf(filename::String, td::PGFPlotsX.TikzDocument; latex_engine::PGFPlotsX.LaTeXEngine, buildflags::Vector{String}, run_count::Int64, tmp::String)
#     @ PGFPlotsX ~/.julia/packages/PGFPlotsX/78BAg/src/tikzdocument.jl:202
#   [3] savesvg(filename::String, td::PGFPlotsX.TikzDocument; latex_engine::PGFPlotsX.LaTeXEngine, buildflags::Vector{String}, keep_pdf::Bool)
#     @ PGFPlotsX ~/.julia/packages/PGFPlotsX/78BAg/src/tikzdocument.jl:272
#   [4] save(filename::String, td::PGFPlotsX.TikzDocument; include_preamble::Bool, latex_engine::PGFPlotsX.LaTeXEngine, buildflags::Vector{String}, dpi::Int64, showing_ide::Bool)
#     @ PGFPlotsX ~/.julia/packages/PGFPlotsX/78BAg/src/tikzdocument.jl:84
#   [5] show(f::IOBuffer, #unused#::MIME{Symbol("image/svg+xml")}, td::PGFPlotsX.TikzDocument)
#     @ PGFPlotsX ~/.julia/packages/PGFPlotsX/78BAg/src/tikzdocument.jl:294
#   [6] _show(io::IOBuffer, mime::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.PGFPlotsXBackend})
#     @ Plots ~/.julia/packages/Plots/QZRtR/src/backends/pgfplotsx.jl:1312
#   [7] #invokelatest#2
#     @ ./essentials.jl:729 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:726 [inlined]
#   [9] show(io::IOBuffer, m::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.PGFPlotsXBackend})
#     @ Plots ~/.julia/packages/Plots/QZRtR/src/output.jl:237
#  [10] sprint(::Function, ::MIME{Symbol("image/svg+xml")}, ::Vararg{Any}; context::Nothing, sizehint::Int64)
#     @ Base ./strings/io.jl:114
#  [11] sprint
#     @ ./strings/io.jl:107 [inlined]
#  [12] _ijulia_display_dict(plt::Plots.Plot{Plots.PGFPlotsXBackend})
#     @ Plots ~/.julia/packages/Plots/QZRtR/src/ijulia.jl:47
#  [13] display_dict
#     @ ~/.julia/packages/Plots/QZRtR/src/init.jl:60 [inlined]
#  [14] display(d::IJulia.InlineDisplay, x::Plots.Plot{Plots.PGFPlotsXBackend})
#     @ IJulia ~/.julia/packages/IJulia/6TIq1/src/inline.jl:98
#  [15] display(x::Any)
#     @ Base.Multimedia ./multimedia.jl:328
#  [16] trajectory3D(x::Vector{StaticArraysCore.MVector{7, Float64}}, u::Vector{StaticArraysCore.MVector{4, Float64}})
#     @ Main.plotter ~/Documents/trajopt-util/jlutil/PIPG/examples/softlanding3D/plotting.jl:34
#  [17] top-level scope
#     @ In[19]:1

# %%
# plotter.visualization_matlab(iX.xopt,iX.uopt)

# %% [markdown]
# ### PIPG

# %%
# plotter.trajectory3D(iX.x,iX.u)
